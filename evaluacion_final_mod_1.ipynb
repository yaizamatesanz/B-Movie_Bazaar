# %%
import re

class Tiendaonline:

    def __init__(self):
        #creamos los atributos
        self.inventario = [] #se crea una lista para almacenar los productos del inventario.
        self.clientes = {} #se crea diccionario para almacenar los clientes y su historial de compra.
        self.ventas_totales = 0.0 #almacena ventas totales.

    def agregar_producto(self, nombre, precio, cantidad):
        for producto in self.inventario:
            if producto["nombre"] == nombre:
                producto["cantidad"] += cantidad
                return
        self.inventario.append({"nombre": nombre, "precio": precio,"cantidad": cantidad})
    
    #con este método agregamos o actualizamos un producto dentro del inventario.

    def ver_inventario(self):
        for producto in self.inventario:
            print(f"Nombre: {producto['nombre']}, Precio: {producto['precio']}€, Cantidad: {producto['cantidad']}")

    #con este método mostramos los detalles del producto.
    #usamos comillas simples dentro del f-strings para las claves del diccionario. Así no nos da error de sintáxis.

    def buscar_producto(self, nombre):
        for producto in self.inventario:
            if producto["nombre"] == nombre:
                print(f"Nombre: {producto['nombre']}, Precio: {producto['precio']}€, Cantidad: {producto['cantidad']}")
        print(f"El producto {nombre} no se encuentra en el inventario.")
        return None

    #buscamos un producto en el inventario por nombre. Si está: muestra sus detalles.

    def actualizar_stock(self, nombre, cantidad):
        for producto in self.inventario:
            if producto["nombre"] == nombre:
                producto["cantidad"] += cantidad
                return
        print(f"El producto {nombre} no se encuentra en el inventario.")

    #actualiza producto si está en inventario.

    def eliminar_producto(self, nombre):
        for producto in self.inventario:
            if producto["nombre"] == nombre:
                self.inventario.remove(producto)
                return
        print(f"El producto {nombre} no se encuentra en el inventario.")

    #elimina producto si está en inventario.

    def calcular_valor_inventario(self):
        valor_total = sum(producto['precio'] * producto['cantidad']
        for producto in self.inventario)
        
        print(f"El valor total del inventario es: {valor_total}€")
        return valor_total
    
    # El for dentro de sum recorre el inventario para calcular el total.

    def buscar_producto_regex(self, patron):
        productos_encontrados = []
        
        for producto in self.inventario:
            if re.search(patron, producto['nombre']):
                productos_encontrados.append(producto)
                print(f"Nombre: {producto['nombre']}, Precio: {producto['precio']}€, Cantidad: {producto['cantidad']}")
        if not productos_encontrados:
            print("No se han encontrado productos con el patrón {patron}")

#1. Importamos librería re (ponemos 'import re' al principio del código) para usar expresiones regulares en el código.
#2. Usamos "re.search" y no "re.match" para buscar el patrón en cualquier parte del string., y no solo al principio.

    def realizar_compra(self):
        carrito = {}
        total_compra = 0

        while True:
            nombre_producto = input("Introduce el nombre del producto que quieres comprar.")
            producto = self.buscar_producto(nombre_producto)

            if producto:
                cantidad = int(input(f"Introduce las unidades de {nombre_producto} que quieres comprar."))
                if cantidad <= producto["cantidad"]:
                    producto["cantidad"] -= cantidad
                    total_compra += producto["precio"] * cantidad
                    carrito[nombre_producto] = carrito.get(nombre_producto, 0) + cantidad
                else:
                    print(f"¡Lo sentimos! No tenemos tantas unidades. Sólo nos quedan: {producto['cantidad']} unidades.")
            else:
                print(f"¡Lo sentimos! No tenemos {nombre_producto} en stock.")

            meter_mas_productos = input("¿Quieres añadir otro producto? Responde sí o no"). lower()
            if meter_mas_productos == "no":
                print("¡Genial! Gracias por comprar en nuestra tienda. ¡Hasta a próxima!")
                break


#1. Diccionario vacío para empezar a crear el "carrito" de productos del usuario.
#2. Llamamos al método "buscar_producto" creado anteriormente, lo usamos para buscar en nuestro inventario.

    def procesar_pago(self):

        while True:
            try:
                total_compra = float(input("Introduce el monto total de la compra."))
                pago = float(input(f"Introduce el monto que vas a pagar."))
                if pago >= self.total_compra:
                    cambio = pago - self.total_compra
                    self.ventas_totales += self.total_compra
                    print(f"Se ha realizado el pago correctamente. Le devolvemos: {cambio}€")
                    break
                else:
                    print(f"Te falta por ingresar {self.total_compra - pago}€")
            except ValueError:
                print("Introduce un monto válido.")

# Maneja el proceso de pago, calcula el cambio y actualiza ventas totales.
# El uso de try...except asegura manejo de errores durante la transacción.

    def agregar_cliente(self, nombre, email):
        if nombre not in self.clientes:
            self.clientes[nombre] = {"email": email, "compras": []}
            print(f"Cliente {nombre} agregado con éxito.")
        else:
            print(f"El cliente {nombre} ya está registrado.")

# Se añade diccionario para almacenar información.

    def ver_clientes(self):
        for nombre, datos in self.clientes.items():
            print(f"Nombre: {nombre}, Email: {datos['email']}")
        else:
            print("No hay clientes registrados.")

# Bucle para recorrer diccionarios y extraer información clave.

    def registrar_compra(self, nombre_cliente, carrito):
        if nombre_cliente in self.clientes:
            total_compra = sum(item['precio'] * item['cantidad'] for item in carrito.values())
            self.clientes[nombre_cliente]['compras'].append({'carrito': carrito, 'total': total_compra})
            self.ventas_totales += total_compra
            print(f"Compra registrada para {nombre_cliente}. Total: {total_compra}€")
        else:
            print(f"El cliente {nombre_cliente} no está registrado.")

# Se registra compra para un cliente ya registrado. Actualiza el historial de compras.

    def ver_compras_cliente(self, nombre_cliente):
        if nombre_cliente in self.clientes:
            compras = self.clientes[nombre_cliente] ["compras"]
            if compras:
                for compra in compras:
                    print(f"Compra: {compra}")
            else:
                print(f"{nombre_cliente} no ha realizado ninguna compra.")
        else:
            print(f"El cliente {nombre_cliente} no está registrado.")
    
    def calcular_ventas_totales(self):
        print(f"Las ventas totales de la tienda son: {self.ventas_totales}€.")
        return self.ventas_totales

# %% [markdown]
# ♥ ♥ ¡Vamos a crear un ejemplo para ranear el código! ♥ ♥

# %%
#1. Creamos una instancia de Tiendaonline.

tiendaserieb = Tiendaonline()

#2. Agregamos productos al iventario.

tiendaserieb.agregar_producto("Cabeza de Eraserhead", 333, 3)
tiendaserieb.agregar_producto("DVD de Videodrome", 25, 37)
tiendaserieb.agregar_producto("Póster de Twin Peaks", 15, 73)
tiendaserieb.agregar_producto("Vinilo de La Mosca", 33, 13)

#3. ¡Vemos todo lo que tenemos en nuestro inventario!

tiendaserieb.ver_inventario()

#4. Realizamos una comprita prueba.

tiendaserieb.realizar_compra()
    #Aquí me encontré mi primer fallo. Escribí 'dvd de videodrome' todo en minúsculas y la máquina me devolvió un:
    #¡Lo sentimos! No tenemos dvd de videodrome en stock.
    #####Nota para mañana: Tengo que revisar dónde meter los lower para que no me de fallo.#####
# Out:
# Nombre: Cabeza de Eraserhead, Precio: 333€, Cantidad: 3
# Nombre: DVD de Videodrome, Precio: 25€, Cantidad: 37
# Nombre: Póster de Twin Peaks, Precio: 15€, Cantidad: 73
# Nombre: Vinilo de La Mosca, Precio: 33€, Cantidad: 13
# El producto  no se encuentra en el inventario.
# ¡Lo sentimos! No tenemos  en stock.
# El producto no no se encuentra en el inventario.
# ¡Lo sentimos! No tenemos no en stock.
